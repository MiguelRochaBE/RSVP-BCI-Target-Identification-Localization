# %%
import os

# %% [markdown]
# # **Reading photos**

# %%
def run_fast_scandir(dir, ext):    
    subfolders, datafiles = [], []

    for f in os.scandir(dir):
        if f.is_dir():
            subfolders.append(f.path)
        if f.is_file():
            if os.path.splitext(f.name)[1].lower() in ext:
                datafiles.append(f.path)

    for dir in list(subfolders):
        sf, f = run_fast_scandir(dir, ext)
        subfolders.extend(sf)
        datafiles.extend(f)
    return subfolders, datafiles

_, photos = run_fast_scandir("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB", ".jpg")

# %%
photos
# Out:
# ['C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123153728_0002_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123154302_0003_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162611_0022_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162618_0023_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162625_0024_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162632_0025_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162639_0026_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162646_0027_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162653_0028_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162700_0029_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162707_0030_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162714_0031_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162721_0032_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162728_0033_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162735_0034_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162742_0035_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162749_0036_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162756_0037_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162803_0038_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162810_0039_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162817_0040_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162824_0041_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162831_0042_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162838_0043_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162845_0044_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162852_0045_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162859_0046_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162906_0047_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162913_0048_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162920_0049_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162927_0050_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162934_0051_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162941_0052_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162948_0053_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123162955_0054_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163002_0055_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163009_0056_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163016_0057_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163023_0058_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163030_0059_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163037_0060_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163044_0061_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163051_0062_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163058_0063_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163105_0064_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163112_0065_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163119_0066_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163126_0067_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163133_0068_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163140_0069_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163147_0070_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163154_0071_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163201_0072_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163208_0073_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163215_0074_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163222_0075_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163229_0076_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163236_0077_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163243_0078_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163250_0079_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163257_0080_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163304_0081_D.JPG',
#  'C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB\\DJI_20240123163311_0082_D.JPG']

# %%
import cv2
import numpy as np

# %%
imgs = []
for im in photos:
    read_im = cv2.imread(im)
    imgs.append(read_im)

# %% [markdown]
# # **Cropping the images**

# %%
cropped_im_dir = "C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/CroppedDronePhotos"

# %%
# 2 x 3 cropping

DIV_HEIGHT = 2
DIV_WIDTH  = 3

if not os.path.exists(cropped_im_dir): # Check if the directory already exists
    os.makedirs(cropped_im_dir, exist_ok=True)
    # exist_ok=True: This is a parameter of the os.makedirs function. When exist_ok is set to True, it ensures that the function
    # does not raise an error if the directory already exists. This is redundant with the condition however.

    for c , im in enumerate(imgs): # Iteration over all the images
        print(f"Cropping image {c + 1}")

        height, width, color_ch = im.shape

        # // Is the integer division (rounded down)
        h = height // DIV_HEIGHT
        w = width // DIV_WIDTH

        for i in range(DIV_HEIGHT): # Horizontal subparts of the image

            start_y = i * h
            end_y = (i + 1) * h

            for j in range(DIV_WIDTH): # Vertical subparts of the image
                
                start_x = j * w
                end_x = (j + 1) * w

                cropped_im = im[start_y:end_y, start_x:end_x]

                if(c+1 < 10):
                    aux = "00"
                elif(c+1 >= 10 and c+1 < 100):
                    aux = "0"
                else:
                    aux = ""
                saving_path = f"{cropped_im_dir}/feupDrone_{aux}{c+1}_{i+1}x{j+1}.jpg"

                cv2.imwrite(saving_path, cropped_im)

else:
    print("Folder already exists.")
# Out:
# Folder already exists.

# %% [markdown]
# # **Finding the centroid of the red object (me) in the image**

# %% [markdown]
# ## Using Deep learning model for human pose estimation

# %%
# https://github.com/opencv/opencv/blob/master/samples/dnn/openpose.py

'''

mod = "graph_opt.pb"
mod_path = f"C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/HumanPoseModel/{mod}"
net = cv2.dnn.readNetFromTensorflow(mod_path) # Importing model (weights)

def pose_estimation(image):
    image = cv2.imread(image)

    height, width, _ = image.shape
    
    inHeight = height 
    inWidth = width
    thr = 0.2

    net.setInput(cv2.dnn.blobFromImage(image, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB = True, crop = False))
    out = net.forward()
    out = out[:,:19,:,:]

    BODY_PARTS = { "Head": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
                    "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
                    "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "Chest": 14,
                    "Background": 15 }

    POSE_PAIRS = [ ["Head", "Neck"], ["Neck", "RShoulder"], ["RShoulder", "RElbow"],
                    ["RElbow", "RWrist"], ["Neck", "LShoulder"], ["LShoulder", "LElbow"],
                    ["LElbow", "LWrist"], ["Neck", "Chest"], ["Chest", "RHip"], ["RHip", "RKnee"],
                    ["RKnee", "RAnkle"], ["Chest", "LHip"], ["LHip", "LKnee"], ["LKnee", "LAnkle"] ]
    

    points = []
    for i in range(len(BODY_PARTS)):
        # Slice heatmap of corresponding body's part.
        heatMap = out[0, i, :, :]

        # Originally, we try to find all the local maximums. To simplify a sample
        # we just find a global one. However only a single pose at the same time
        # could be detected this way.
        _, conf, _, point = cv2.minMaxLoc(heatMap)
        x = (width * point[0]) / out.shape[3]
        y = (height * point[1]) / out.shape[2]

        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)

    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] and points[idTo]:
            cv2.line(image, points[idFrom], points[idTo], (0, 0, 0), 3)
            cv2.ellipse(image, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)
            cv2.ellipse(image, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv2.getTickFrequency() / 1000

    return image


_, cropped_images = run_fast_scandir(cropped_im_dir, ".jpg")
for count, im in enumerate(cropped_images):
    pose = pose_estimation(im)
    cv2.imshow("Human detection", pose)
    cv2.waitKey(1500)
    cv2.destroyAllWindows()
    '''
# Out:
# '\n\nmod = "graph_opt.pb"\nmod_path = f"C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/HumanPoseModel/{mod}"\nnet = cv2.dnn.readNetFromTensorflow(mod_path) # Importing model (weights)\n\ndef pose_estimation(image):\n    image = cv2.imread(image)\n\n    height, width, _ = image.shape\n    \n    inHeight = height \n    inWidth = width\n    thr = 0.2\n\n    net.setInput(cv2.dnn.blobFromImage(image, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB = True, crop = False))\n    out = net.forward()\n    out = out[:,:19,:,:]\n\n    BODY_PARTS = { "Head": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,\n                    "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,\n                    "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "Chest": 14,\n                    "Background": 15 }\n\n    POSE_PAIRS = [ ["Head", "Neck"], ["Neck", "RShoulder"], ["RShoulder", "RElbow"],\n                    ["RElbow", "RWrist"], ["Neck", "LShoulder"], ["LShoulder", "LElbow"],\n                    ["LElbow", "LWrist"], ["Neck", "Chest"], ["Chest", "RHip"], ["RHip", "RKnee"],\n                    ["RKnee", "RAnkle"], ["Chest", "LHip"], ["LHip", "LKnee"], ["LKnee", "LAnkle"] ]\n    \n\n    points = []\n    for i in range(len(BODY_PARTS)):\n        # Slice heatmap of corresponding body\'s part.\n        heatMap = out[0, i, :, :]\n\n        # Originally, we try to find all the local maximums. To simplify a sample\n        # we just find a global one. However only a single pose at the same time\n        # could be detected this way.\n        _, conf, _, point = cv2.minMaxLoc(heatMap)\n        x = (width * point[0]) / out.shape[3]\n        y = (height * point[1]) / out.shape[2]\n\n        # Add a point if it\'s confidence is higher than threshold.\n        points.append((int(x), int(y)) if conf > thr else None)\n\n    for pair in POSE_PAIRS:\n        partFrom = pair[0]\n        partTo = pair[1]\n        assert(partFrom in BODY_PARTS)\n        assert(partTo in BODY_PARTS)\n\n        idFrom = BODY_PARTS[partFrom]\n        idTo = BODY_PARTS[partTo]\n\n        if points[idFrom] and points[idTo]:\n            cv2.line(image, points[idFrom], points[idTo], (0, 0, 0), 3)\n            cv2.ellipse(image, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)\n            cv2.ellipse(image, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)\n\n    t, _ = net.getPerfProfile()\n    freq = cv2.getTickFrequency() / 1000\n\n    return image\n\n\n_, cropped_images = run_fast_scandir(cropped_im_dir, ".jpg")\nfor count, im in enumerate(cropped_images):\n    pose = pose_estimation(im)\n    cv2.imshow("Human detection", pose)\n    cv2.waitKey(1500)\n    cv2.destroyAllWindows()\n    '

# %% [markdown]
# ## Using a color mask

# %% [markdown]
# ### Finding the specific HSV values of the target object (red color shirt)

# %%
object_color_image = cv2.imread("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/DroneIm_FEUP_DB/targetObj_colorFinding.jpeg")
cv2.imshow('Test Image', object_color_image)
cv2.waitKey(3000)
cv2.destroyAllWindows()

# Convert BGR to HSV
hsv_image = cv2.cvtColor(object_color_image, cv2.COLOR_BGR2HSV)

# Extract the H channel
h_channel = hsv_image[:, :, 0]
s_channel = hsv_image[:, :, 1]
v_channel = hsv_image[:, :, 2]

# Calculate the average value of all color channels
average_h = np.mean(h_channel)
average_s = np.mean(v_channel)
average_v = np.mean(v_channel)

# Calculate the standard variation of all color channels

std_h = np.std(h_channel)
std_s = np.std(s_channel)
std_v = np.std(v_channel)

print(f"Average H value: {average_h} +/- {std_h} | Average S value: {average_s} +/- {std_s} | Average V value: {average_v} +/- {std_v}" )
# Out:
# Average H value: 173.3404081632653 +/- 0.5904338051811634 | Average S value: 206.37795918367348 +/- 11.356905797258193 | Average V value: 206.37795918367348 +/- 18.90470203680489

# %% [markdown]
# ### Apllying the correct HSV ranges for the target objects

# %% [markdown]
# The sub-images that only demonstrated the ceilling were eliminated, thus remaining 261 images on the DB (vs 378 originally)

# %%
import pandas as pd

# %%
SCREEN_WIDTH_PX = 1920
SCREEN_HEIGHT_PX = 1080

SCREEN_DIAGONAL_SIZE_INCH = 27

def visual_angle(object_x_px, object_y_px, H_image_width_px, V_image_width_px, screen_width_px, screen_height_px, screen_diagonal_size_inch):
    
    # https://www.reddit.com/r/oculus/comments/1dmcsh/default_eye_to_screen_distance/ corresponds to measurement
    #observer_distance_mm = 40 # in mm for the HMD (Oculus Rift)
    OBSERVER_DISTANCE_MM = 800 # in mm for the C1 computer

    # Inches to mm the screen size
    screen_diagonal_size_mm = screen_diagonal_size_inch * 25.4 

    # Angle of the diagonal of the screen
    width_height_angle = np.arctan(screen_height_px/screen_width_px) # C_oposed/C_adjacent

    # Width and Height of the screen in mm
    screen_width_mm = round(np.cos(width_height_angle) * screen_diagonal_size_mm, 3)
    screen_height_mm = round(np.sin(width_height_angle) * screen_diagonal_size_mm, 3)
    
    # Convert the size of the image in pixels to mm
    H_image_width_mm = (screen_width_mm * H_image_width_px)/screen_width_px
    V_image_width_mm = (screen_height_mm * V_image_width_px)/screen_height_px

    # Visual angle of the image
    H_image_width_deg = np.degrees(2 * (np.arctan(H_image_width_mm / (OBSERVER_DISTANCE_MM * 2))))
    V_image_width_deg = np.degrees(2 * (np.arctan(V_image_width_mm / (OBSERVER_DISTANCE_MM * 2))))

    # How many degrees in the visual field represents one pixel in the images
    H_visual_angle_per_px = H_image_width_deg / H_image_width_px 
    V_visual_angle_per_px = V_image_width_deg / V_image_width_px

    H_object_x_deg = (object_x_px - (H_image_width_px / 2)) * H_visual_angle_per_px
    V_object_x_deg = (object_y_px - (V_image_width_px / 2)) * V_visual_angle_per_px

    return H_object_x_deg, V_object_x_deg

# %%
# This is for the PsycgoPy -> trial -> trialImage -> Layout -> Size[w,h] $

wPx = 1134
hPx = 1344 

print(f"Size [{round(hPx * 0.5 / wPx, 3)}, 0.5]")

wPx = 1134 * 0.5 # px
hPx = 1344 * 0.5 # px

# Now we have to define how to devide the visual field for the VR headset
# In the original study had a width of 11.5 x 11.8 degrees and 640 x 640 in pixels. 
# Also, a threshold of +/- 1.2 degrees to classify the images for the LVF and RVF 

#observer_distance_mm = 40
OBSERVER_DISTANCE_MM = 800

# Inches to mm the screen size
screen_diagonal_size_mm = SCREEN_DIAGONAL_SIZE_INCH * 25.4 

# Angle of the diagonal of the screen
width_height_angle = np.arctan(SCREEN_HEIGHT_PX/SCREEN_WIDTH_PX) # C_oposed/C_adjacent

# Width and Height of the screen in mm
screen_width_mm = round(np.cos(width_height_angle) * screen_diagonal_size_mm, 3)
screen_height_mm = round(np.sin(width_height_angle) * screen_diagonal_size_mm, 3)

# Convert the size of the image in pixels to mm
H_image_width_mm = (screen_width_mm * wPx)/SCREEN_WIDTH_PX
V_image_width_mm = (screen_height_mm * hPx)/SCREEN_HEIGHT_PX

# Visual angle of the image
H_image_width_deg = np.degrees(2 * (np.arctan(H_image_width_mm / (OBSERVER_DISTANCE_MM * 2))))
V_image_width_deg = np.degrees(2 * (np.arctan(V_image_width_mm / (OBSERVER_DISTANCE_MM * 2))))

print("\nWidth of the image in degrees: ", round(H_image_width_deg,3))
print("Height of the image in degrees: ", round(V_image_width_deg,3))

# Paper on Eccentricity of the target stimuli and the N2pc performance: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7160023/pdf/nihms-1065363.pdf 
#print("\nNew threshold (H): ", round((1.2 * H_image_width_deg / 11.5),3))
#print("New threshold (V): ", round((1.2 * V_image_width_deg / 11.5),3))
# Out:
# Size [0.593, 0.5]
#
# Width of the image in degrees:  12.591
# Height of the image in degrees:  14.899

# %%
H_th = 1.314 # Degrees
V_th = 1.555

_, cropped_images = run_fast_scandir(cropped_im_dir, ".jpg")

clearance = 3   # Clearance: 3 x std
h_clearance = 5 # Clearance: 5 x std (Hue/color channel)

all_hsvIms = []
all_conditions = []
all_centroids = []
all_visual_angles = []
all_stim_types = []

t_count = 0
nt_count = 0

for count, im in enumerate(cropped_images):

    # Reads the image using OpenCV
    im = im.replace( '/', '\\')
    img = cv2.imread(im)
    img = cv2.resize(img, None, fx=0.5, fy=0.5)

    all_hsvIms.append(im)
        
    # Image sizes
    width, height, _ = img.shape
    print(f"------- Image {count + 1} -------")
    print(f"Image size: {width} x {height} px")

    # Converts the image from BGR to HSV color space
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) 
    #The image is converted to the HSV (Hue, Saturation, Value) color space because it provides a more 
    #intuitive way to represent colors, making it easier to isolate a specific color range, such as red.
    # This is because the whole color information is on the first channel, Hue.

    # Defines the range of red color in HSV (https://colorpicker.me)
    lower_red = np.array([average_h - h_clearance * std_h, average_s - clearance * std_s, average_v - clearance * std_v]) 
    upper_red = np.array([average_h + h_clearance * std_h, average_s + clearance * std_s, average_v + clearance * std_v])

    # Thresholds the image with a mask to get only red pixels
    ''' 
    This binarizes the portions of the image contained between the lower_red and upper_red range.
    The pixel values contained in that HSV range will have the value of 1 and the rest the value 
    of 0 on the binarized image.
    '''
    mask = cv2.inRange(hsv_img, lower_red, upper_red)

    # Finds contours in the binary image
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        # Finds the largest contour (assumed to be the red object)
        largest_contour = max(contours, key=cv2.contourArea)

        # Calculates the centroid of the largest contour
        moments = cv2.moments(largest_contour)

        # Checks if moments['m00'] is not zero before division
        if moments['m00'] != 0:
            # Target image was identified
            all_conditions.append("Target")
            t_count += 1
        
            # Image Processing: Moment of Image for Object Detection - https://www.youtube.com/watch?v=RCodqRopMHs
            ''' 
            M00     = Area of the target object in the image (Counts of 1 in the binarized image)
            M10/M00 = Center coordinate of the target object in the x axis
            M01/M00 = Center coordinate of the target object in the y axis
            M11     = Spread of the target object on the x and y directions
            '''
            centroid_x = int(moments['m10'] / moments['m00'])
            centroid_y = int(moments['m01'] / moments['m00'])
            print(f"Target found - Coordinates: [{centroid_x}, {centroid_y}]")
            all_centroids.append([f"x={centroid_x}, y={centroid_y}"])

            # Calculates horizontal and vertical visual angle
            x_VA, y_VA = visual_angle(centroid_x, centroid_y, width, height, SCREEN_WIDTH_PX, SCREEN_HEIGHT_PX, SCREEN_DIAGONAL_SIZE_INCH)

            if (x_VA > H_th):
                x_stim_type = "RVF"
            elif (x_VA < -H_th):
                x_stim_type = "LVF"
            else:
                x_stim_type = "CVF"

            if(y_VA > V_th):
                y_stim_type = "TVF"
            elif (y_VA < -V_th):
                y_stim_type = "BVF"
            else:
                y_stim_type = "CVF"
             
            all_visual_angles.append([f"x={round(x_VA, 3)},y={round(y_VA, 3)}"])
            all_stim_types.append(x_stim_type + "_" + y_stim_type)

            # Draws a circle at the centroid
            cv2.circle(img, (centroid_x, centroid_y), 12, (255, 50, 50), -1) # radius = 15; thickness = -1; blueish = (255, 50, 50) in BGR
            
            # Displays the image with the centroid to check if the centroid is being determined correctly   
            cv2.imshow('Target image', img)
            cv2.waitKey(1000) # Time that image stays on the screen in ms (Value of 0 makes the window stay open until manually closed)
            cv2.destroyAllWindows()  
            
            
        else:
            # Non target image was identified
            nt_count += 1
            
            all_conditions.append("NonTarget")
            all_centroids.append("0")
            all_visual_angles.append("0")
            all_stim_types.append("0")
            
            print("Non target image")
    else:
        # Non target image was identified
        all_conditions.append("NonTarget")
        all_centroids.append("0")
        all_visual_angles.append("0")
        all_stim_types.append("0")

        print("Non target image")
        
        # Supervising/checking algor
        cv2.imshow('Non-target image',img)
        cv2.waitKey(200)
        cv2.destroyAllWindows()
# Out:
# ------- Image 1 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 2 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 3 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [178, 345]
# ------- Image 4 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 5 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 6 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 7 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 8 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 9 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 10 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 11 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [345, 67]
# ------- Image 12 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 13 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 14 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 15 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 16 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 17 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 18 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 19 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 20 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 21 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 22 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 23 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [505, 62]
# ------- Image 24 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 25 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 26 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 27 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 28 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 29 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 30 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 31 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 32 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 33 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 34 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 35 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 36 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 37 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [196, 410]
# ------- Image 38 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 39 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 40 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 41 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 42 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 43 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 44 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 45 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 46 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 47 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 48 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 49 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 50 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 51 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [168, 361]
# ------- Image 52 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 53 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 54 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 55 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 56 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 57 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 58 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 59 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 60 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 61 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 62 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 63 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 64 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 65 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 66 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 67 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 68 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 69 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 70 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 71 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 72 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 73 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 74 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 75 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 76 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 77 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 78 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 79 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 80 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 81 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 82 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 83 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 84 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 85 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 86 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 87 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 88 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 89 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [605, 113]
# ------- Image 90 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 91 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 92 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 93 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 94 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 95 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 96 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 97 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 98 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 99 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 100 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 101 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 102 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 103 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 104 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [350, 259]
# ------- Image 105 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 106 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 107 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 108 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 109 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 110 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 111 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 112 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 113 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 114 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 115 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 116 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 117 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 118 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 119 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 120 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 121 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 122 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 123 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 124 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 125 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 126 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 127 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 128 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 129 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [349, 155]
# ------- Image 130 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 131 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 132 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 133 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 134 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 135 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 136 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 137 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 138 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 139 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 140 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 141 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 142 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 143 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [658, 408]
# ------- Image 144 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 145 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 146 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 147 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 148 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 149 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 150 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 151 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 152 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 153 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 154 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 155 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 156 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 157 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 158 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 159 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 160 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 161 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [631, 495]
# ------- Image 162 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 163 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 164 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 165 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 166 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 167 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 168 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 169 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 170 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 171 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 172 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 173 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 174 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 175 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 176 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 177 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 178 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 179 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 180 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 181 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [29, 28]
# ------- Image 182 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 183 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 184 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 185 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 186 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [55, 498]
# ------- Image 187 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 188 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 189 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [392, 203]
# ------- Image 190 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 191 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 192 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 193 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 194 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 195 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 196 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 197 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 198 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 199 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 200 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 201 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 202 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 203 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 204 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 205 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 206 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 207 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 208 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 209 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 210 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 211 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 212 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 213 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 214 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 215 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 216 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 217 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 218 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 219 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 220 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [384, 57]
# ------- Image 221 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 222 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 223 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 224 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [466, 443]
# ------- Image 225 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 226 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 227 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 228 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 229 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 230 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 231 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 232 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 233 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 234 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 235 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 236 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 237 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 238 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 239 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 240 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 241 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 242 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 243 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 244 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 245 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 246 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 247 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 248 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 249 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 250 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 251 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 252 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 253 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 254 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 255 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 256 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 257 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 258 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 259 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 260 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 261 -------
# Image size: 567 x 672 px
# Non target image

# %%
# Checking size of arrays

print(len(all_hsvIms))
print(len(all_conditions))
print(len(all_centroids))
print(len(all_visual_angles))
print(len(all_stim_types))
# Out:
# 261
# 261
# 261
# 261
# 261

# %% [markdown]
# ### Writting the dataframe into an excel sheet

# %%
import random

# %%
0.10*150
# Out:
# 15.0

# %%
# Check for duplicates based on entire rows
unique = np.unique(all_hsvIms)

excel_file = "FEUP_droneImages.xlsx"
protocol_path = "C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/"

if not os.path.exists(protocol_path + excel_file):
    if len(unique) == len(all_hsvIms):
        # Creating pandas Dataframe
        df = pd.DataFrame({"Image" : all_hsvIms, "Condition" : all_conditions, "Centroid" : all_centroids, "Visual_angle" : all_visual_angles, "Stimulus_type" : all_stim_types})
        
        # Slicing the required number of Non Target images to maintain the 10% oddball rule
        n_targets = len(df[df["Condition"] == "Target"])
        p = 10 # (%) Proportion of targets to non targets
        sliced_df = pd.concat([df[df["Condition"] == "Target"], df[df["Condition"] == "NonTarget"][0:n_targets * p - n_targets]], ignore_index = True) 
        print("Dataframe size: ", sliced_df.shape)
        
        # Random shuffling the concatenated data 3x
        permutation1 = np.random.permutation(sliced_df.index)
        sliced_df = sliced_df.iloc[permutation1]
        permutation2 = np.random.permutation(sliced_df.index)
        sliced_df = sliced_df.iloc[permutation2]
        permutation3 = np.random.permutation(sliced_df.index)
        sliced_df = sliced_df.iloc[permutation3]

        # Writting to excel
        sliced_df.to_excel(protocol_path + excel_file, sheet_name = "sheet1", index = False)
    else:
        print("Duplicate entries found!")
else:
    print("File already exists!")
# Out:
# Dataframe size:  (150, 5)
