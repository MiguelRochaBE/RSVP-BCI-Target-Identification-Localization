# %%
import os

# %% [markdown]
# # **Reading photos**

# %%
def run_fast_scandir(dir, ext):    
    subfolders, datafiles = [], []

    for f in os.scandir(dir):
        if f.is_dir():
            subfolders.append(f.path)
        if f.is_file():
            if os.path.splitext(f.name)[1].lower() in ext:
                datafiles.append(f.path)

    for dir in list(subfolders):
        sf, f = run_fast_scandir(dir, ext)
        subfolders.extend(sf)
        datafiles.extend(f)
    return subfolders, datafiles

train_im_folder = "C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/MADALENA_APR_18_DJI"
# test_im_folder = "C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/FEUP_JAN_21_DJI"
_, photos = run_fast_scandir(train_im_folder, ".jpg")

# %%
import cv2
import numpy as np

# %%
imgs = []
for im in photos:
    read_im = cv2.imread(im)
    imgs.append(read_im)

# %% [markdown]
# # **Cropping the images**

# %%
# Train Images:
# cropped_im_dir = "C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/Cropped_FEUP_JAN_21_DJI"

# Test images: 
cropped_im_dir = "C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/Cropped_MADALENA_APR_18_DJI"

# %%
# 2 x 3 cropping

DIV_HEIGHT = 2
DIV_WIDTH  = 3

if not os.path.exists(cropped_im_dir): # Check if the directory already exists
    os.makedirs(cropped_im_dir, exist_ok=True)
    # exist_ok=True: This is a parameter of the os.makedirs function. When exist_ok is set to True, it ensures that the function
    # does not raise an error if the directory already exists. This is redundant with the condition however.

    for c , im in enumerate(imgs): # Iteration over all the images
        print(f"Cropping image {c + 1}")

        height, width, color_ch = im.shape

        # // Is the integer division (rounded down)
        h = height // DIV_HEIGHT
        w = width // DIV_WIDTH

        for i in range(DIV_HEIGHT): # Horizontal subparts of the image

            start_y = i * h
            end_y = (i + 1) * h

            for j in range(DIV_WIDTH): # Vertical subparts of the image
                
                start_x = j * w
                end_x = (j + 1) * w

                cropped_im = im[start_y:end_y, start_x:end_x]

                if(c+1 < 10):
                    aux = "00"
                elif(c+1 >= 10 and c+1 < 100):
                    aux = "0"
                else:
                    aux = ""
                saving_path = f"{cropped_im_dir}/madalenaDrone_{aux}{c+1}_{i+1}x{j+1}.jpg"

                cv2.imwrite(saving_path, cropped_im)

else:
    print("Folder already exists.")
# Out:
# Folder already exists.

# %% [markdown]
# # **Finding the centroid of the red object (me) in the image**

# %% [markdown]
# ## Using Deep learning model for human pose estimation

# %%
# https://github.com/opencv/opencv/blob/master/samples/dnn/openpose.py

'''

mod = "graph_opt.pb"
mod_path = f"C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/HumanPoseModel/{mod}"
net = cv2.dnn.readNetFromTensorflow(mod_path) # Importing model (weights)

def pose_estimation(image):
    image = cv2.imread(image)

    height, width, _ = image.shape
    
    inHeight = height 
    inWidth = width
    thr = 0.2

    net.setInput(cv2.dnn.blobFromImage(image, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB = True, crop = False))
    out = net.forward()
    out = out[:,:19,:,:]

    BODY_PARTS = { "Head": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
                    "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
                    "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "Chest": 14,
                    "Background": 15 }

    POSE_PAIRS = [ ["Head", "Neck"], ["Neck", "RShoulder"], ["RShoulder", "RElbow"],
                    ["RElbow", "RWrist"], ["Neck", "LShoulder"], ["LShoulder", "LElbow"],
                    ["LElbow", "LWrist"], ["Neck", "Chest"], ["Chest", "RHip"], ["RHip", "RKnee"],
                    ["RKnee", "RAnkle"], ["Chest", "LHip"], ["LHip", "LKnee"], ["LKnee", "LAnkle"] ]
    

    points = []
    for i in range(len(BODY_PARTS)):
        # Slice heatmap of corresponding body's part.
        heatMap = out[0, i, :, :]

        # Originally, we try to find all the local maximums. To simplify a sample
        # we just find a global one. However only a single pose at the same time
        # could be detected this way.
        _, conf, _, point = cv2.minMaxLoc(heatMap)
        x = (width * point[0]) / out.shape[3]
        y = (height * point[1]) / out.shape[2]

        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)

    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] and points[idTo]:
            cv2.line(image, points[idFrom], points[idTo], (0, 0, 0), 3)
            cv2.ellipse(image, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)
            cv2.ellipse(image, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv2.getTickFrequency() / 1000

    return image


_, cropped_images = run_fast_scandir(cropped_im_dir, ".jpg")
for count, im in enumerate(cropped_images):
    pose = pose_estimation(im)
    cv2.imshow("Human detection", pose)
    cv2.waitKey(1500)
    cv2.destroyAllWindows()
    '''
# Out:
# '\n\nmod = "graph_opt.pb"\nmod_path = f"C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/HumanPoseModel/{mod}"\nnet = cv2.dnn.readNetFromTensorflow(mod_path) # Importing model (weights)\n\ndef pose_estimation(image):\n    image = cv2.imread(image)\n\n    height, width, _ = image.shape\n    \n    inHeight = height \n    inWidth = width\n    thr = 0.2\n\n    net.setInput(cv2.dnn.blobFromImage(image, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB = True, crop = False))\n    out = net.forward()\n    out = out[:,:19,:,:]\n\n    BODY_PARTS = { "Head": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,\n                    "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,\n                    "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "Chest": 14,\n                    "Background": 15 }\n\n    POSE_PAIRS = [ ["Head", "Neck"], ["Neck", "RShoulder"], ["RShoulder", "RElbow"],\n                    ["RElbow", "RWrist"], ["Neck", "LShoulder"], ["LShoulder", "LElbow"],\n                    ["LElbow", "LWrist"], ["Neck", "Chest"], ["Chest", "RHip"], ["RHip", "RKnee"],\n                    ["RKnee", "RAnkle"], ["Chest", "LHip"], ["LHip", "LKnee"], ["LKnee", "LAnkle"] ]\n    \n\n    points = []\n    for i in range(len(BODY_PARTS)):\n        # Slice heatmap of corresponding body\'s part.\n        heatMap = out[0, i, :, :]\n\n        # Originally, we try to find all the local maximums. To simplify a sample\n        # we just find a global one. However only a single pose at the same time\n        # could be detected this way.\n        _, conf, _, point = cv2.minMaxLoc(heatMap)\n        x = (width * point[0]) / out.shape[3]\n        y = (height * point[1]) / out.shape[2]\n\n        # Add a point if it\'s confidence is higher than threshold.\n        points.append((int(x), int(y)) if conf > thr else None)\n\n    for pair in POSE_PAIRS:\n        partFrom = pair[0]\n        partTo = pair[1]\n        assert(partFrom in BODY_PARTS)\n        assert(partTo in BODY_PARTS)\n\n        idFrom = BODY_PARTS[partFrom]\n        idTo = BODY_PARTS[partTo]\n\n        if points[idFrom] and points[idTo]:\n            cv2.line(image, points[idFrom], points[idTo], (0, 0, 0), 3)\n            cv2.ellipse(image, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)\n            cv2.ellipse(image, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv2.FILLED)\n\n    t, _ = net.getPerfProfile()\n    freq = cv2.getTickFrequency() / 1000\n\n    return image\n\n\n_, cropped_images = run_fast_scandir(cropped_im_dir, ".jpg")\nfor count, im in enumerate(cropped_images):\n    pose = pose_estimation(im)\n    cv2.imshow("Human detection", pose)\n    cv2.waitKey(1500)\n    cv2.destroyAllWindows()\n    '

# %% [markdown]
# ## Using a color mask

# %% [markdown]
# ### Finding the specific HSV values of the target object (red color shirt)

# %%
object_color_image = cv2.imread("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/MADALENA_APR_18_DJI/targetObj_colorFinding.jpeg")
cv2.imshow('Test Image', object_color_image)
cv2.waitKey(3000)
cv2.destroyAllWindows()

# Convert BGR to HSV
hsv_image = cv2.cvtColor(object_color_image, cv2.COLOR_BGR2HSV)
cv2.imwrite("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/MADALENA_APR_18_DJI/targetObj_colorFinding_HSV.jpeg", hsv_image)

# Extract the H channel
h_channel = hsv_image[:, :, 0]
s_channel = hsv_image[:, :, 1]
v_channel = hsv_image[:, :, 2]

# Calculate the average value of all color channels
average_h = np.mean(h_channel)
average_s = np.mean(v_channel)
average_v = np.mean(v_channel)

# Calculate the standard variation of all color channels

std_h = np.std(h_channel)
std_s = np.std(s_channel)
std_v = np.std(v_channel)

print(f"Average H value: {average_h} +/- {std_h} | Average S value: {average_s} +/- {std_s} | Average V value: {average_v} +/- {std_v}" )
# Out:
# Average H value: 19.638383838383838 +/- 1.4535020106942877 | Average S value: 227.7621212121212 +/- 31.68070708342838 | Average V value: 227.7621212121212 +/- 34.607546901957186

# %% [markdown]
# ### Function that displays the color HSV range determined according to cv2 package and finds the corresponding HEX color code

# %%
def hex_color_code(hue, saturation, value):

    # Convert HSV to BGR (OpenCV uses BGR by default)
    hsv_color = np.uint8([[([hue, saturation, value])]])  # Reshape for OpenCV
    bgr_color = cv2.cvtColor(hsv_color, cv2.COLOR_HSV2BGR)[0][0]

    # Extract BGR channels
    blue = bgr_color[0]
    green = bgr_color[1]
    red = bgr_color[2]

    # Convert each channel to a 2-digit hex string with zero-padding
    hex_code = "#" + format(red, '02x') + format(green, '02x') + format(blue, '02x')

    # Print the hex code
    print(f"Hue (0-179): {round(hue,3)} | Saturation (0-255): {round(saturation,3)} | Value (0-255): {round(value,3)} | Hex code: {hex_code}")

# %%
hex_color_code(173.340, 206.377, 206.377)
# Out:
# Hue (0-179): 173.34 | Saturation (0-255): 206.377 | Value (0-255): 206.377 | Hex code: #ce284e

# %% [markdown]
# ### Apllying the correct HSV ranges for the target objects

# %% [markdown]
# The sub-images that only demonstrated the ceilling were eliminated, thus remaining 261 images on the DB (vs 378 originally)

# %%
import pandas as pd

# %%
_, cropped_images = run_fast_scandir(cropped_im_dir, ".jpg")


# Train range

#clearance = 3   # Clearance: 3 x std
#h_clearance = 5 # Clearance: 5 x std (Hue/color channel)

# Test range

clearance = 2.4  # Clearance: 3 x std
h_clearance = 1.2 # Clearance: 5 x std (Hue/color channel)

all_hsvIms = []
all_conditions = []
all_centroids = []

t_count = 0
nt_count = 0

int_cent = []

# Defines the range of red color in HSV (https://colorpicker.me)
lower_red = np.array([average_h - h_clearance * std_h, average_s - clearance * std_s, average_v - clearance * std_v]) 
upper_red = np.array([average_h + h_clearance * std_h, average_s + clearance * std_s, average_v + clearance * std_v])

for count, im in enumerate(cropped_images):

    # Reads the image using OpenCV
    im = im.replace( '/', '\\')
    img = cv2.imread(im)
    img = cv2.resize(img, None, fx=0.5, fy=0.5)

    all_hsvIms.append(im)
        
    # Image sizes
    height, width, _ = img.shape
    print(f"------- Image {count + 1} -------")
    print(f"Image size: {height} x {width} px")

    # Converts the image from BGR to HSV color space
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) 
    
    #The image is converted to the HSV (Hue, Saturation, Value) color space because it provides a more 
    #intuitive way to represent colors, making it easier to isolate a specific color range, such as red.
    # This is because the whole color information is on the first channel, Hue.
        
    # Thresholds the image with a mask to get only red pixels
    ''' 
    This binarizes the portions of the image contained between the lower_red and upper_red range.
    The pixel values contained in that HSV range will have the value of 1 and the rest the value 
    of 0 on the binarized image.
    '''
    mask = cv2.inRange(hsv_img, lower_red, upper_red)

    # Finds contours in the binary image
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    '''
    cv2.RETR_EXTERNAL: This retrieves only the extreme outer contours. This means it will identify the outermost 
    boundaries of connected components in the foreground (white) regions of the mask image.

    cv2.CHAIN_APPROX_SIMPLE: This method stores only the endpoints of the contours, resulting in a more compressed 
    representation. This is useful for most basic contour analysis tasks as it reduces memory usage and processing time.
    '''

    if contours:
        # Finds the largest contour (assumed to be the red object)
        largest_contour = max(contours, key=cv2.contourArea)

        # Calculates the centroid of the largest contour
        moments = cv2.moments(largest_contour)

        # Checks if moments['m00'] is not zero before division
        if moments['m00'] != 0:
            # Target image was identified
            all_conditions.append("Target")
            t_count += 1

            if(t_count == 1):
                print("Saving images...")
                cv2.imwrite("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/ImTese/HSV_target.png", hsv_img)
                cv2.imwrite("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/ImTese/HSVmask_target.png", mask)

            # Image Processing: Moment of Image for Object Detection - https://www.youtube.com/watch?v=RCodqRopMHs
            ''' 
            M00     = Area of the target object in the image (Counts of 1 in the binarized image)
            M10/M00 = Center coordinate of the target object in the x axis
            M01/M00 = Center coordinate of the target object in the y axis
            M11     = Spread of the target object on the x and y directions
            '''
            centroid_x = int(moments['m10'] / moments['m00'])
            centroid_y = int(moments['m01'] / moments['m00'])
            print(f"Target found - Coordinates: [{centroid_x}, {centroid_y}]")
            all_centroids.append([f"x={centroid_x}, y={centroid_y}"])

            int_cent.append([centroid_x, centroid_y])

            # Draws a circle at the centroid
            cv2.circle(img, (centroid_x, centroid_y), 12, (255, 50, 50), -1) # radius = 15; thickness = -1; blueish = (255, 50, 50) in BGR
            
            # Displays the image with the centroid to check if the centroid is being determined correctly   
            '''
            cv2.imshow('Target image', img)
            cv2.waitKey(800) # Time that image stays on the screen in ms (Value of 0 makes the window stay open until manually closed)
            cv2.destroyAllWindows()  
            '''
            
        else:
            # Non target image was identified
            nt_count += 1
            
            all_conditions.append("NonTarget")
            all_centroids.append("0")
            
            print("Non target image")
    else:
        # Non target image was identified
        nt_count += 1

        all_conditions.append("NonTarget")
        all_centroids.append("0")
        
        print("Non target image")
        
        # Supervising/checking algor
        '''
        cv2.imshow('Non-target image',img)
        cv2.waitKey(400)
        cv2.destroyAllWindows()
        '''
    
    # Finding the HEX color codes of the HSV color range determined
    if (count == len(cropped_images) - 1):
        print("-----------------------------------------------")
        print("Lower HEX color value: ")
        hex_color_code(lower_red[0], lower_red[1], lower_red[2])
        print("Upper HEX color value: ")
        hex_color_code(upper_red[0], upper_red[1], upper_red[2])
        print("\n")
# Out:
# ------- Image 1 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 2 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 3 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 4 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 5 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 6 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 7 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 8 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 9 -------
# Image size: 567 x 672 px
# Saving images...
# Target found - Coordinates: [374, 399]
# ------- Image 10 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 11 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 12 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 13 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 14 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 15 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [482, 405]
# ------- Image 16 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 17 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 18 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 19 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 20 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 21 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 22 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 23 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 24 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 25 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 26 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 27 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 28 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 29 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 30 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 31 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 32 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 33 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 34 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 35 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 36 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 37 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 38 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 39 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 40 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 41 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 42 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [586, 179]
# ------- Image 43 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 44 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 45 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 46 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 47 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 48 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 49 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 50 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 51 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 52 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 53 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 54 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 55 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 56 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 57 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 58 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 59 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 60 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 61 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 62 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 63 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 64 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 65 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 66 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 67 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 68 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 69 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 70 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 71 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 72 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 73 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 74 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 75 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 76 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 77 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 78 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 79 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [475, 294]
# ------- Image 80 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 81 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 82 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 83 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 84 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 85 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 86 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [439, 133]
# ------- Image 87 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 88 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 89 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 90 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 91 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 92 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 93 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 94 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 95 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 96 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 97 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 98 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 99 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 100 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [346, 153]
# ------- Image 101 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 102 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 103 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 104 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 105 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 106 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 107 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 108 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [262, 208]
# ------- Image 109 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [409, 358]
# ------- Image 110 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 111 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 112 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 113 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 114 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 115 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 116 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 117 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 118 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 119 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 120 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 121 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 122 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 123 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [592, 205]
# ------- Image 124 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 125 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 126 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 127 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 128 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 129 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 130 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [114, 412]
# ------- Image 131 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 132 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 133 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 134 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 135 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 136 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 137 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 138 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 139 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 140 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 141 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 142 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 143 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 144 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 145 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 146 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 147 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 148 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 149 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 150 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 151 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 152 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 153 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 154 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 155 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 156 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 157 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 158 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 159 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 160 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 161 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 162 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 163 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 164 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 165 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 166 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [56, 372]
# ------- Image 167 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 168 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 169 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 170 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 171 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 172 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 173 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 174 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 175 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 176 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 177 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 178 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 179 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 180 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 181 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 182 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 183 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 184 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 185 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 186 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 187 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 188 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [637, 487]
# ------- Image 189 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [33, 78]
# ------- Image 190 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 191 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 192 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 193 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 194 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 195 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 196 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 197 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 198 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 199 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 200 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 201 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 202 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 203 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 204 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 205 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 206 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 207 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 208 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 209 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 210 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 211 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 212 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 213 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 214 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 215 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 216 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 217 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 218 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [204, 169]
# ------- Image 219 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 220 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 221 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 222 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 223 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 224 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 225 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 226 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 227 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 228 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 229 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 230 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 231 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 232 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 233 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 234 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 235 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 236 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 237 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 238 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 239 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 240 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 241 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 242 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 243 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [141, 371]
# ------- Image 244 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 245 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 246 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 247 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 248 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 249 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 250 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 251 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 252 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 253 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 254 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 255 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 256 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [542, 231]
# ------- Image 257 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 258 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 259 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 260 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 261 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 262 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [564, 69]
# ------- Image 263 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 264 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 265 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [143, 280]
# ------- Image 266 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 267 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 268 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 269 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 270 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 271 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 272 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 273 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 274 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 275 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 276 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 277 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 278 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 279 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [215, 409]
# ------- Image 280 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 281 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 282 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [336, 471]
# ------- Image 283 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 284 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 285 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 286 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 287 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 288 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 289 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 290 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 291 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 292 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 293 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 294 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 295 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 296 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 297 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 298 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 299 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 300 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 301 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 302 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 303 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 304 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 305 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 306 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 307 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 308 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [165, 326]
# ------- Image 309 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 310 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 311 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 312 -------
# Image size: 567 x 672 px
# Non target image
# ------- Image 313 -------
# Image size: 567 x 672 px
# Target found - Coordinates: [336, 71]
# -----------------------------------------------
# Lower HEX color value:
# Hue (0-179): 17.894 | Saturation (0-255): 151.728 | Value (0-255): 144.704 | Hex code: #906b3b
# Upper HEX color value:
# Hue (0-179): 21.383 | Saturation (0-255): 303.796 | Value (0-255): 310.82 | Hex code: #36332c

# %%
t_count
# Out:
# 22

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

int_cent = np.array(int_cent)

figure(figsize = (10, 8))

plt.scatter(int_cent[:,0], int_cent[:,1], s = 20);
plt.xlabel("Image horizontal dimension (px)")
plt.ylabel("Image vertical dimension (px)")
plt.title("Distribution of targets")

plt.axvline(x = 278, color = 'g', linestyle = ':', linewidth = 2)
plt.axvline(x = 394, color = 'g', linestyle = ':', linewidth = 2)

plt.axhline(y = 226, color = 'r', linestyle = ':', linewidth = 2)
plt.axhline(y = 341, color = 'r', linestyle = ':', linewidth = 2)

plt.xlim([0, width]);
plt.ylim([height, 0])
# Out:
# (567.0, 0.0)

# %%
len(int_cent)
# Out:
# 22

# %%
print((176.388 - 170.388) / 3)
print((100 * (240.449 - 173.307) / 255 / 3))
print((100 * (263.092 - 149.664) / 255 / 3))

print(((240.449 - 173.307) / 3))
print(((263.092 - 149.664) / 3))
# Out:
# 2.0
# 8.776732026143794
# 14.827189542483659
# 22.380666666666674
# 37.809333333333335

# %%
hex_color_code(170.388 + 2, 172.307 + 22, 149.664 + 37)
# Out:
# Hue (0-179): 172.388 | Saturation (0-255): 194.307 | Value (0-255): 186.664 | Hex code: #ba2c52

# %%
# Checking size of arrays

print(len(all_hsvIms))
print(len(all_conditions))
print(len(all_centroids))
# Out:
# 313
# 313
# 313

# %%
#_, photos = run_fast_scandir("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/Cropped_MADALENA_APR_18_DJI - Cópia/", ".png")

# %%
'''
from PIL import Image 

def convert_and_delete_jpgs(image_dir, output_dir):
  """
  Converts all JPG images in the specified directory to PNG format, saves them in another folder, 
  and deletes the original JPGs.

  Args:
      image_dir (str): The path to the directory containing the images.
      output_dir (str): The path to the directory where converted images will be saved.
  """
  for filename in os.listdir(image_dir):
    if filename.lower().endswith("png"):
      # Construct the full path to the image file
      image_path = os.path.join(image_dir, filename)

      try:
        # Open the image using Pillow
        img = Image.open(image_path)

        # Extract the filename without extension
        base_name, _ = os.path.splitext(filename)

        # Construct the new filename and path within the output directory
        new_filename = f"{base_name}.jpg"
        output_path = os.path.join(output_dir, new_filename)

        # Save the image in PNG format to the output directory
        img.save(output_path)

        # Delete the original JPG after successful conversion (**Caution:** This is permanent deletion)
        os.remove(image_path)

        print(f"Successfully converted '{filename}' to PNG and saved to '{output_path}', original deleted.")
      except (IOError, OSError) as e:
        print(f"Error processing '{filename}': {e}")

# Example usage (replace 'path/to/your/images' and 'path/to/save/converted' with your actual directories)
convert_and_delete_jpgs("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/Cropped_MADALENA_APR_18_DJI - Cópia/", cropped_im_dir)
'''
# Out:
# '\nfrom PIL import Image \n\ndef convert_and_delete_jpgs(image_dir, output_dir):\n  """\n  Converts all JPG images in the specified directory to PNG format, saves them in another folder, \n  and deletes the original JPGs.\n\n  Args:\n      image_dir (str): The path to the directory containing the images.\n      output_dir (str): The path to the directory where converted images will be saved.\n  """\n  for filename in os.listdir(image_dir):\n    if filename.lower().endswith("png"):\n      # Construct the full path to the image file\n      image_path = os.path.join(image_dir, filename)\n\n      try:\n        # Open the image using Pillow\n        img = Image.open(image_path)\n\n        # Extract the filename without extension\n        base_name, _ = os.path.splitext(filename)\n\n        # Construct the new filename and path within the output directory\n        new_filename = f"{base_name}.jpg"\n        output_path = os.path.join(output_dir, new_filename)\n\n        # Save the image in PNG format to the output directory\n        img.save(output_path)\n\n        # Delete the original JPG after successful conversion (**Caution:** This is permanent deletion)\n        os.remove(image_path)\n\n        print(f"Successfully converted \'{filename}\' to PNG and saved to \'{output_path}\', original deleted.")\n      except (IOError, OSError) as e:\n        print(f"Error processing \'{filename}\': {e}")\n\n# Example usage (replace \'path/to/your/images\' and \'path/to/save/converted\' with your actual directories)\nconvert_and_delete_jpgs("C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/RSVP aerial imagery dataset/Cropped_MADALENA_APR_18_DJI - Cópia/", cropped_im_dir)\n'

# %% [markdown]
# ### Writting the dataframe into an excel sheet

# %%
import random

# %%
# Check for duplicates based on entire rows
unique = np.unique(all_hsvIms)

excel_file = "FEUP_droneImages.xlsx"
protocol_path = "C:/Users/migue/OneDrive/Ambiente de Trabalho/Tese/AcquisitionProtocols/"

if not os.path.exists(protocol_path + excel_file):
    if len(unique) == len(all_hsvIms):
        # Creating pandas Dataframe
        df = pd.DataFrame({"Image" : all_hsvIms, "Condition" : all_conditions, "Centroid" : all_centroids})
        
        # Slicing the required number of Non Target images to maintain the 10% oddball rule
        n_targets = len(df[df["Condition"] == "Target"])
        p = 10 # (%) Proportion of targets to non targets
        sliced_df = pd.concat([df[df["Condition"] == "Target"], df[df["Condition"] == "NonTarget"][0:n_targets * p - n_targets]], ignore_index = True) 
        print("Dataframe size: ", sliced_df.shape)
        
        # Random shuffling the concatenated data 3x
        permutation1 = np.random.permutation(sliced_df.index)
        sliced_df = sliced_df.iloc[permutation1]
        permutation2 = np.random.permutation(sliced_df.index)
        sliced_df = sliced_df.iloc[permutation2]
        permutation3 = np.random.permutation(sliced_df.index)
        sliced_df = sliced_df.iloc[permutation3]

        # Writting to excel
        sliced_df.to_excel(protocol_path + excel_file, sheet_name = "sheet1", index = False)
    else:
        print("Duplicate entries found!")
else:
    print("File already exists!")
# Out:
# File already exists!
